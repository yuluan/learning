# %%
print('hello')
# Out:
# hello

# %% [markdown]
# **黑体**

# %% [markdown]
# * 第一部分
# * 第二部分

# %% [markdown]
# **向熊**

# %% [markdown]
# *我是大笨猪*

# %% [markdown]
# 1. 第一部分
# 1. 第二部分
# 1. 第三部分

# %% [markdown]
# $e^{i\pi}+1=0$

# %% [markdown]
# $\sum_{(\forall i)()}

# %% [markdown]
# ![123](D:\360安全浏览器下载\)

# %% [markdown]
# Image(filename='D:\360安全浏览器下载\1.JPEG',width=200)

# %%
import graphviz

# %%
import graphviz

# %%
import graphviz as gra

# %%
from IPython.display import Image

# %%
import IPython

# %%
from IPython.display import Image

# %%
Image(filename='D:/1.jpg',width=200)

# %%
Image(filename='D:/1.jpg',width=800)

# %% [markdown]
# <img src='D:/360安全浏览器下载/1.jpg',width=800>

# %% [markdown]
# <img src='D:/360安全浏览器下载/1.jpg',width=800>

# %% [markdown]
# <img src='D:/360安全浏览器下载/1.jpg',width=800>

# %% [markdown]
# <img src='D:\360安全浏览器下载\1.jpg',width=100>
